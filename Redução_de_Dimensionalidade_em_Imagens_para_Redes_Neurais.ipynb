# %% [markdown]
# <a href="https://colab.research.google.com/github/luxlox/reducao-de-dimensionalidade-em-imagens/blob/main/Redu%C3%A7%C3%A3o_de_Dimensionalidade_em_Imagens_para_Redes_Neurais.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab import files
import numpy as np

# === 1. Upload da Imagem ===
uploaded = files.upload()

# Pega o nome do arquivo enviado
file_name = list(uploaded.keys())[0]

# Carrega a imagem com OpenCV
img = cv2.imread(file_name)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# === 2. Converter para Escala de Cinza ===
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# === 3. Binarização (Threshold) ===
limiar = 127
_, img_binary = cv2.threshold(img_gray, limiar, 255, cv2.THRESH_BINARY)

# === 4. Exibição dos Resultados ===
plt.figure(figsize=(14,4))

plt.subplot(1,3,1)
plt.imshow(img_rgb)
plt.title("Imagem Original")
plt.axis('off')

plt.subplot(1,3,2)
plt.imshow(img_gray, cmap="gray")
plt.title("Imagem em Escala de Cinza")
plt.axis('off')

plt.subplot(1,3,3)
plt.imshow(img_binary, cmap="gray")
plt.title("Imagem Binarizada")
plt.axis('off')

plt.show()
# Out:
#      <input type="file" id="files-1cdc2a9b-0198-49cd-84b1-966435575ebd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1cdc2a9b-0198-49cd-84b1-966435575ebd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
